# %% [markdown]
# # Titanic Case
# ## Team
# - Klas: 3
# - Team: 15
# - Teamleden:
#     - Ömer
#     - Max
#     - Nassim
#     - Emmelotte
# - Kaggle Score: ~0.68
# - Presentatiedatum: 17 september 2021 10:00 - 11:00 met Jerome in C4.22

# %% [markdown]
# ### Imports voor de analyse
# - Pandas voor het gebruik van Dataframes en Series
# - MatPlotLib voor het gebruik van bar, histogram, boxplot en scatter plots
# - OS om de werkmap locatie te vinden
# - Random om een willekeurig getal te krijgen

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
# %matplotlib inline

# %% [markdown]
# Zie de werkmap

# %%
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: C:\Users\Omwro\Documents\~code\hva\se4\DataScienceGithub\Titanic

# %% [markdown]
# ## Train

# %% [markdown]
# Lees de data van 'train.csv'

# %%
train_csv_file = 'train.csv'
df_train = pd.read_csv(train_csv_file)
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Passagiers klasse analyse
# Voor elke mogelijke passagiers klasse, toon het aantal overlevenden en sterfgevallen.
# Zorg ook voor een bar plot.

# %%
# Analyse op basis van P class 1
first_class = df_train[df_train['Pclass'] == 1]
first_class_count = len(first_class)
first_class_survivor = first_class[first_class['Survived'] == 1]
first_class_survivor_count = len(first_class_survivor)
first_class_dead_count = first_class_count - first_class_survivor_count
print("First class survivor count: ",first_class_survivor_count)
print("First class death count: ",first_class_dead_count)

# Analyse op basis van P class 2
second_class = df_train[df_train['Pclass'] == 2]
second_class_count = len(second_class)
second_class_survivor = second_class[second_class['Survived'] == 1]
second_class_survivor_count = len(second_class_survivor)
second_class_dead_count = second_class_count - second_class_survivor_count
print("Second class survivor count: ",second_class_survivor_count)
print("Second class death count: ",second_class_dead_count)

# Analyse op basis van P class 3
third_class = df_train[df_train['Pclass'] == 3]
third_class_count = len(third_class)
third_class_survivor = third_class[third_class['Survived'] == 1]
third_class_survivor_count = len(third_class_survivor)
third_class_dead_count = third_class_count - third_class_survivor_count
print("Third class survivor count:",third_class_survivor_count)
print("Third class death  count:",third_class_dead_count)

# Bar plot
plt.bar("1th Class Survivors", first_class_survivor_count)
plt.bar("1th Class Deaths", first_class_dead_count)
plt.bar("2th Class Survivors", second_class_survivor_count)
plt.bar("2th Class Deaths", second_class_dead_count)
plt.bar("3th Class Survivors", third_class_survivor_count)
plt.bar("3th Class Deaths", third_class_dead_count)
plt.title("All passengers")
plt.xlabel("Passengers outcome")
plt.ylabel("Amount of passengers")
plt.xticks(rotation=45)
plt.show()
# Out:
# First class survivor count:  136
# First class death count:  80
# Second class survivor count:  87
# Second class death count:  97
# Third class survivor count: 119
# Third class death  count: 372

# %% [markdown]
# ### Passagiers geslacht analyse
# Voor elke geslacht, toon het aantal overlevenden en sterfgevallen.
# Zorg ook voor een bar plot.

# %%
# Analyse op basis van het geslacht man
sex_male = df_train[df_train['Sex'] == 'male']
sex_male_count = len(sex_male)
sex_male_surivors = sex_male[sex_male['Survived'] == 1]
sex_male_surivors_count = len(sex_male_surivors)
sex_male_dead_count = sex_male_count - sex_male_surivors_count
print("Sex Male survivor count:",sex_male_surivors_count)
print("Sex Male death count:",sex_male_dead_count)

# Analyse op basis van het geslacht vrouw
sex_female = df_train[df_train['Sex'] == 'female']
sex_female_count = len(sex_female)
sex_female_surivors = sex_female[sex_female['Survived'] == 1]
sex_female_surivors_count = len(sex_female_surivors)
sex_female_dead_count = sex_female_count - sex_female_surivors_count
print("Sex Female survivor count:",sex_female_surivors_count)
print("Sex Female death count:",sex_female_dead_count)

# Bar plot
plt.bar("Sex Male Survivors", sex_male_surivors_count)
plt.bar("Sex Male Deaths", sex_male_dead_count)
plt.bar("Sex Female Survivors", sex_female_surivors_count)
plt.bar("Sex Female Deaths", sex_female_dead_count)
plt.title("All passengers")
plt.xlabel("Passengers outcome")
plt.ylabel("Amount of passengers")
plt.xticks(rotation=45)
plt.show()
# Out:
# Sex Male survivor count: 109
# Sex Male death count: 468
# Sex Female survivor count: 233
# Sex Female death count: 81

# %% [markdown]
# ### Passagiers leeftijd analyse
# Voor elke mogelijke passagiers leeftijd, toon het aantal overlevenden en sterfgevallen.
# Zorg ook voor een bar plot.

# %%
# Nieuwe dicts voor de overlevers en doden
train_survivors = df_train[df_train['Survived'] == 1]
train_deaths = df_train[df_train['Survived'] == 0]

# Alle lege waardes eruit filteren
train_survivors = train_survivors[train_survivors['Age'] >= 0]
train_deaths = train_deaths[train_deaths['Age'] >= 0]

# Boxplot
plt.boxplot([train_survivors['Age'], train_deaths['Age']], labels=['Survivors', 'Deaths'])
plt.title("All passengers")
plt.xlabel("Passengers age")
plt.ylabel("Amount of passengers")
plt.xticks(rotation=45)
plt.show()

# Histogram
plt.hist(train_survivors["Age"], histtype='step', label="Survivors")
plt.hist(train_deaths["Age"], histtype='step', label="Deaths")
plt.title("All passengers")
plt.xlabel("Passengers age")
plt.ylabel("Amount of passengers")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ## Test

# %% [markdown]
# Lees de data van 'test.csv'

# %%
test_csv_file = 'test.csv'
df_test = pd.read_csv(test_csv_file)
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### Overlevingskans berekenen
# Met de code hieronder berekenen we de overlevingskans van een passagier met de attributen
# van de passagier zoals: klasse, geslacht en leeftijd.
# Dit wordt berekend door de passagiers met dezelfde attributen uit de 'train.csv' te filteren.
# Vervolgens kunnen we het overlevingskans berekenen in percentages door naar de verhouding
# te kijken van het aantal overlevenden en sterfgevallen.
# De overlevingskans wordt gebruikt in het algoritme.

# %%
# df_train_XXX = c: class, s: sex, a: age
df_train_c = df_train[df_train['Pclass'] == 1]
df_train_cs = df_train_c[df_train_c['Sex'] == 'male']
df_train_csa = df_train_cs[df_train_cs["Age"] <= 18]
passenger_count = len(df_train_csa) / len(df_train) * 100
survival_chance = len(df_train_csa[df_train_csa['Survived'] == 1]) / len(df_train_csa) * 100
print(survival_chance, "%")
# Out:
# 80.0 %

# %% [markdown]
# ### Algoritme
# Met de code hieronder berekenen we of de passagier het Titanic gebeurtenis zal overleven.
# Het algoritme filtert per passagier op zijn of haar klasse, leeftijd en geslacht.
# Met de code hierboven hebben we de overlevingskans per passagier handmatig berekent.
# Vervolgens pakken we een willekeurig overlevingskans en vergelijken we het met elkaar.
# Als de passagiers overlevingskans onder de willekeurige overlevingskans ligt,
# dan overleefd de passagier het.
# Als de passagiers overlevingskans boven de willekeurige overlevingskans ligt,
# dan sterft de passagier.

# %%
# Kolom 'Survived' toevoegen met de standaard waarde van 0
df_test['Survived'] = 0

# Iterate over het dataframe 'df_test' waarbij we de index en het passenger waarde ophalen
for index, pas in df_test.iterrows() :
    # Maak een dict voor de passenger class
    pas_class = pas['Pclass']
    # Maak een dict voor de passenger age
    pas_age = pas["Age"]
    # Maak een dict voor de passenger sex
    pas_sex = pas["Sex"]
    
    # Bereken de overlevingskans van de passenger in percentage
    survival_chance = random.randint(1, 100)

    # Algoritme waarbij de passenger overlevingskans wordt berekend
    if pas_class == 1:
        if pas_age <= 18:
            if pas_sex == 'male' :
                if survival_chance <= 80 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 91 :
                    df_test.at[index, 'Survived'] = 1
        elif pas_age <= 30 :
            if pas_sex == 'male' :
                if survival_chance <= 50 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 94 :
                    df_test.at[index, 'Survived'] = 1
        elif pas_age <= 50 :
            if pas_sex == 'male' :
                if survival_chance <= 47 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 96 :
                    df_test.at[index, 'Survived'] = 1
        else:
            if pas_sex == 'male' :
                if survival_chance <= 19 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 100 :
                    df_test.at[index, 'Survived'] = 1
    elif pas_class == 2:
        if pas_age <= 18:
            if pas_sex == 'male' :
                if survival_chance <= 60 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 100 :
                    df_test.at[index, 'Survived'] = 1
        elif pas_age <= 30 :
            if pas_sex == 'male' :
                if survival_chance <= 19 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 94 :
                    df_test.at[index, 'Survived'] = 1
        elif pas_age <= 50 :
            if pas_sex == 'male' :
                if survival_chance <= 16 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 93 :
                    df_test.at[index, 'Survived'] = 1
        else:
            if pas_sex == 'male' :
                if survival_chance <= 8 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 67 :
                    df_test.at[index, 'Survived'] = 1
    else:
        if pas_age <= 18:
            if pas_sex == 'male' :
                if survival_chance <= 22 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 51 :
                    df_test.at[index, 'Survived'] = 1
        elif pas_age <= 30 :
            if pas_sex == 'male' :
                if survival_chance <= 17 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 51 :
                    df_test.at[index, 'Survived'] = 1
        elif pas_age <= 50 :
            if pas_sex == 'male' :
                if survival_chance <= 16 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 46 :
                    df_test.at[index, 'Survived'] = 1
        else:
            if pas_sex == 'male' :
                if survival_chance <= 0 :
                    df_test.at[index, 'Survived'] = 1
            else :
                if survival_chance <= 100 :
                    df_test.at[index, 'Survived'] = 1

# Maak een dict aan van de dataframe 'df_test' waarbij alleen de kolommen 'PassengerId' en 'Survived' worden getoond
df_final = df_test[['PassengerId', 'Survived']]
# Bestandsnaam voor de df_final data
df_final_file_name = 'titanic_test_kaggle_submission.csv'
# Maak een csv file van de dict hierboven, waarbij de index niet wordt getoond
df_final.to_csv(df_final_file_name, index=False)
df_final
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         1
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %% [markdown]
# ### Passagiers leeftijd en kosten analyse
# Voor elke passagier, tonen we in een Scatterplot de overlevenden en sterfgevallen
# op basis van de passagiers leeftijd en de kosten.

# %%
# Per category een dict
test_survivors = df_test[df_test['Survived'] == 1]
test_deaths = df_test[df_test['Survived'] == 0]

# Scatter plot
plt.scatter(test_survivors['Age'], test_survivors['Fare'], marker="D", label="Survivors")
plt.scatter(test_deaths['Age'], test_deaths['Fare'], marker="D", label="Deaths")
plt.title("Alle passengers op basis van \n leeftijd en ticket prijs", c="g")
plt.xlabel("Leeftijd van de passengers", c="g")
plt.ylabel("Ticket kosten in euro", c="g")
plt.tick_params(axis='x', colors='g')
plt.tick_params(axis='y', colors='g')
plt.legend()
plt.show()

# %% [markdown]
# ### Passagiers geslacht analyse
# Voor elke geslacht, toon het aantal overlevenden en sterfgevallen.
# Zorg ook voor een bar plot.

# %%
# Analyse op basis van het geslacht man
sex_male = df_test[df_test['Sex'] == 'male']
sex_male_count = len(sex_male)
sex_male_surivors = sex_male[sex_male['Survived'] == 1]
sex_male_surivors_count = len(sex_male_surivors)
sex_male_dead_count = sex_male_count - sex_male_surivors_count
print("Sex Male survivor count:",sex_male_surivors_count)
print("Sex Male death count:",sex_male_dead_count)

# Analyse op basis van het geslacht vrouw
sex_female = df_test[df_test['Sex'] == 'female']
sex_female_count = len(sex_female)
sex_female_surivors = sex_female[sex_female['Survived'] == 1]
sex_female_surivors_count = len(sex_female_surivors)
sex_female_dead_count = sex_female_count - sex_female_surivors_count
print("Sex Female survivor count:",sex_female_surivors_count)
print("Sex Female death count:",sex_female_dead_count)

# Bar plot
plt.bar("Sex Male Survivors", sex_male_surivors_count)
plt.bar("Sex Male Deaths", sex_male_dead_count)
plt.bar("Sex Female Survivors", sex_female_surivors_count)
plt.bar("Sex Female Deaths", sex_female_dead_count)
plt.title("Comparison of chance of survival between men and women")
plt.xlabel("Passengers outcome")
plt.ylabel("Amount of passengers")
plt.xticks(rotation=45)
plt.show()
# Out:
# Sex Male survivor count: 53
# Sex Male death count: 213
# Sex Female survivor count: 119
# Sex Female death count: 33

# %% [markdown]
# ### Passagiers klasse analyse
# Voor elke mogelijke passagiers klasse, toon het aantal overlevenden en sterfgevallen.
# Zorg ook voor een bar plot.

# %%
# Analyse op basis van P class 1
first_class = df_test[df_test['Pclass'] == 1]
first_class_count = len(first_class)
first_class_survivor = first_class[first_class['Survived'] == 1]
first_class_survivor_count = len(first_class_survivor)
first_class_dead_count = first_class_count - first_class_survivor_count
print("First class survivor count: ",first_class_survivor_count)
print("First class death count: ",first_class_dead_count)

# Analyse op basis van P class 2
second_class = df_test[df_test['Pclass'] == 2]
second_class_count = len(second_class)
second_class_survivor = second_class[second_class['Survived'] == 1]
second_class_survivor_count = len(second_class_survivor)
second_class_dead_count = second_class_count - second_class_survivor_count
print("Second class survivor count: ",second_class_survivor_count)
print("Second class death count: ",second_class_dead_count)

# Analyse op basis van P class 3
third_class = df_test[df_test['Pclass'] == 3]
third_class_count = len(third_class)
third_class_survivor = third_class[third_class['Survived'] == 1]
third_class_survivor_count = len(third_class_survivor)
third_class_dead_count = third_class_count - third_class_survivor_count
print("Third class survivor count:",third_class_survivor_count)
print("Third class death count:",third_class_dead_count)

# Maken van bar chart
plt.bar("1st Class Survivors", first_class_survivor_count)
plt.bar("1st Class Deaths", first_class_dead_count)
plt.bar("2nd Class Survivors", second_class_survivor_count)
plt.bar("2nd Class Deaths", second_class_dead_count)
plt.bar("3rd Class Survivors", third_class_survivor_count)
plt.bar("3rd Class Deaths", third_class_dead_count)
plt.title("Comparison of chance of survival between classes")
plt.xlabel("Passengers outcome")
plt.ylabel("Amount of passengers")
plt.xticks(rotation=45)
plt.show()
# Out:
# First class survivor count:  70
# First class death count:  37
# Second class survivor count:  37
# Second class death count:  56
# Third class survivor count: 65
# Third class death count: 153
